# %%
from bs4 import BeautifulSoup

# %%
from bs4 import BeautifulSoup

with open("../data_input/Lemmatized-Greek/tlg0001.tlg001.perseus-grc2.xml") as file:
    soup = BeautifulSoup(file, 'html.parser')

# %%
print(soup.prettify())
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
for lemma in soup.find_all('l1'):
    print(lemma.get_text())
# Out:
# as many l1 elements as the lemmas found in PerseusUnderPhilologic for
#               the relevant word form AND morphological analysis
# ἄρχω
# Φοῖβος
# κλέος
# φώς
# μιμνήσκω
# ὁ
# ὅς
# Πόντος
# στόμα
# καί
# πέτρα
# βασιλεύς
# ἐφημοσύνη
# Πελίας
# χρύσεος
# κῶας
# εὔζυγος
# ἐλαύνω
# Ἀργός
# γάρ
# Πελίας
# φάτις
# κλύω
# ὡς
# ὀπίσω
# μοῖρα
# μένω
# στυγερός
# ὅδε
# ἀνήρ
# ὅστις
# ὁράω
# δημός
# δῆμος
# οἰοπέδιλος
# ὑπό
# ἐνεσία
# ἐννεσία
# δαμάζω
# δηρός
# δέ
# οὐ
# μετέπειτα
# βάξις
# Ἰάσων
# ῥεῖθρον
# κίω
# πούς
# Ἄναυρος
# ἄλλος
# μέν
# ἐκσῴζω
# ὑπό
# ἰλύς
# ἄλλος
# δέ
# ἔνερθε
# καταλείπω
# αὖθι
# ἐνίσχω
# ἱκνέομαι
# δέ
# Πελίας
# αὐτοσχεδόν
# ἀντιβολέω
# εἰλαπίνη
# ὅς
# ὅς2
# πατήρ
# Ποσειδῶν
# καί
# ἄλλος
# ῥέζω
# Ἥρα
# δέ
# Πελασγίς
# οὐ
# ἀλεγίζω
# αἶψα
# δέ
# εἰσοράω
# φράζω
# καί
# ἆθλος
# τύνω
# ναυτιλία
# πολυκηδής
# ὄφρα
# ἐν
# πόντος
# ἤ
# καί
# ἀλλοδαπός
# μετά
# ἀνήρ
# νόστος
# ὄλλυμι
# ναῦς
# μέν
# οὖν
# πρόσθεν
# ἐπικλείω
# ἐπικλείω2
# ἀοιδός
# Ἄργος2
# Ἀθήνη
# ...
